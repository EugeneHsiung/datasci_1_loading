# %% [markdown]
# <a href="https://colab.research.google.com/github/EugeneHsiung/datasci_1_loading/blob/main/HHA507W1_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loading packages

# %%
import pandas as pd
import seaborn as sns
import plotly as pit

# %% [markdown]
# # Examples with CSV files

# %% [markdown]
# ## Description of Columns
#
# ### *   'Year' is the year the dataset was obtained
# ### *   'LocationAbbr' and 'LocationDesc' is the location from the dataset
#
# ### *  'Topic type' is the type of survey
# ### *  'TopicDesc' is the description of topic
# ### *  'MeasureDesc' is the measurment of topic
# ### *  'DataSource' is where the data is from
# ### *  'Response' is the response from the data
# ### *  'Data_Value_Unit' and 'Data_Value_Type' is the value type from the data

# %% [markdown]
# ## Example 1: Youth Tobacco Survey CSV File

# %%
YouthTobacco = pd.read_csv('YouthTobaccoData.csv')

# %%
print(YouthTobacco)
# Out:
#        YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0      2004           OH           Ohio  Tobacco Use – Survey Data
# 1      2008           AL        Alabama  Tobacco Use – Survey Data
# 2      2015           WV  West Virginia  Tobacco Use – Survey Data
# 3      2005           IL       Illinois  Tobacco Use – Survey Data
# 4      2005           CT    Connecticut  Tobacco Use – Survey Data
# ...     ...          ...            ...                        ...
# 10595  2002           KS         Kansas  Tobacco Use – Survey Data
# 10596  2015           IL       Illinois  Tobacco Use – Survey Data
# 10597  2010           WI      Wisconsin  Tobacco Use – Survey Data
# 10598  2009           LA      Louisiana  Tobacco Use – Survey Data
# 10599  2010           DE       Delaware  Tobacco Use – Survey Data
#
#                            TopicDesc  \
# 0              Cigarette Use (Youth)
# 1              Cigarette Use (Youth)
# 2      Smokeless Tobacco Use (Youth)
# ...

# %%
YouthTobacco.head(10)
# Out:
#    YEAR LocationAbbr   LocationDesc                  TopicType  \
# 0  2004           OH           Ohio  Tobacco Use – Survey Data
# 1  2008           AL        Alabama  Tobacco Use – Survey Data
# 2  2015           WV  West Virginia  Tobacco Use – Survey Data
# 3  2005           IL       Illinois  Tobacco Use – Survey Data
# 4  2005           CT    Connecticut  Tobacco Use – Survey Data
# 5  2009           CT    Connecticut  Tobacco Use – Survey Data
# 6  2001           ID          Idaho  Tobacco Use – Survey Data
# 7  2004           VT        Vermont  Tobacco Use – Survey Data
# 8  2007           CT    Connecticut  Tobacco Use – Survey Data
# 9  2006           PA   Pennsylvania  Tobacco Use – Survey Data
#
#                        TopicDesc     MeasureDesc DataSource  Response  \
# 0          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# 1          Cigarette Use (Youth)  Smoking Status        YTS      Ever
# ...

# %% [markdown]
# ## Example 2: Specific Chronic Conditions

# %%
SCC = pd.read_csv('ChronicConditions.csv')

# %%
SCC

# %%
SCC [0:10]

# %% [markdown]
# ## Example 3: AH Monthly Provisional Counts of Deaths

# %%
AHMonth = pd.read_csv('AHMonth.csv')

# %%
AHMonth

# %%
AHMonth[0:10]

# %% [markdown]
# # Examples with XLSX

# %% [markdown]
# ## Example 1: Cardiac Surgery and Percutaneous Sugery by Hospital

# %%
cardiac = pd.read_excel('Cardiac.xls')

# %%
cardiac
# Out:
#       Facility ID           Hospital Name          Detailed Region  \
# 0               1         Albany Med. Ctr         Capital District
# 1            1045   White Plains Hospital  NY Metro - New Rochelle
# 2            1438   Bellevue Hospital Ctr                Manhattan
# 3            1439     Beth Israel Med Ctr                Manhattan
# 4            1178  Bronx-Lebanon-Cncourse                    Bronx
# ...           ...                     ...                      ...
# 2807            0     NYS - All Hospitals           New York State
# 2808            0     NYS - All Hospitals           New York State
# 2809            0     NYS - All Hospitals           New York State
# 2810            0     NYS - All Hospitals           New York State
# 2811            0     NYS - All Hospitals           New York State
#
#                        Region            Procedure Year of Hospital Discharge  \
# 0            Capital District              All PCI                       2016
# ...

# %%
cardiac [0:10]
# Out:
#    Facility ID           Hospital Name          Detailed Region  \
# 0            1         Albany Med. Ctr         Capital District
# 1         1045   White Plains Hospital  NY Metro - New Rochelle
# 2         1438   Bellevue Hospital Ctr                Manhattan
# 3         1439     Beth Israel Med Ctr                Manhattan
# 4         1178  Bronx-Lebanon-Cncourse                    Bronx
# 5         1286  Brookdale Hosp Med Ctr                    Kings
# 6          116     Arnot Ogden Med Ctr   Western NY - Rochester
# 7          746  Bassett Medical Center         Capital District
# 8         1456    Mount Sinai Hospital                Manhattan
# 9         1438   Bellevue Hospital Ctr                Manhattan
#
#                     Region            Procedure Year of Hospital Discharge  \
# 0         Capital District              All PCI                       2016
# 1  NY Metro - New Rochelle    Non-Emergency PCI                       2015
# ...

# %% [markdown]
# ## Example 2: Heart Failure Mortality

# %%
HFM = pd.read_excel('HFM.xls')

# %%
HFM
# Out:
#       County Name  County Code  Health Topic Number  \
# 0  New York State          999                    2
# 1  New York State          999                    2
# 2  New York State          999                    2
# 3  New York State          999                    2
# 4  New York State          999                    2
# 5  New York State          999                    2
# 6  New York State          999                    2
# 7  New York State          999                    2
# 8  New York State          999                    2
# 9  New York State          999                    2
#
#                         Health Topic Indicator ID  \
# 0  Cardiovascular Disease Indicators          d10
# 1  Cardiovascular Disease Indicators          d10
# 2  Cardiovascular Disease Indicators          d10
# 3  Cardiovascular Disease Indicators          d10
# 4  Cardiovascular Disease Indicators          d10
# 5  Cardiovascular Disease Indicators          d10
# ...

# %%
HFM [0:10]
# Out:
#       County Name  County Code  Health Topic Number  \
# 0  New York State          999                    2
# 1  New York State          999                    2
# 2  New York State          999                    2
# 3  New York State          999                    2
# 4  New York State          999                    2
# 5  New York State          999                    2
# 6  New York State          999                    2
# 7  New York State          999                    2
# 8  New York State          999                    2
# 9  New York State          999                    2
#
#                         Health Topic Indicator ID  \
# 0  Cardiovascular Disease Indicators          d10
# 1  Cardiovascular Disease Indicators          d10
# 2  Cardiovascular Disease Indicators          d10
# 3  Cardiovascular Disease Indicators          d10
# 4  Cardiovascular Disease Indicators          d10
# 5  Cardiovascular Disease Indicators          d10
# ...

# %% [markdown]
# ## Example 3: Hepatitis B Birth Dose

# %%
Hep = pd.read_excel('HepatitisB.xls')

# %%
Hep
# Out:
#     Year  Facility ID       County Region  \
# 0   2014          739       Ostego   CDRO
# 1   2014          324     Franklin   CDRO
# 2   2014            1       Albany   CDRO
# 3   2014          325     Franklin   CDRO
# 4   2014          116      Chemung    WRO
# ..   ...          ...          ...    ...
# 82  2014         1045  Westchester   MARO
# 83  2014          511       Nassau   MARO
# 84  2014          208         Erie    WRO
# 85  2014          103   Chautauqua    WRO
# 86  2014         1153      Wyoming    WRO
#
#                               Hospital Name  Total Births  Infants <2000 Gm  \
# 0                 A O Fox Memorial Hospital           260                 0
# 1                     Adirondack Med Center           145                 1
# 2            Albany Medical Center Hospital          2058               245
# 3                 Alice Hyde Medical Center           243                 5
# ...

# %%
Hep[0:10]
# Out:
#    Year  Facility ID        County Region  \
# 0  2014          739        Ostego   CDRO
# 1  2014          324      Franklin   CDRO
# 2  2014            1        Albany   CDRO
# 3  2014          325      Franklin   CDRO
# 4  2014          116       Chemung    WRO
# 5  2014           85        Cayuga  CNYRO
# 6  2014          848   Schenectady   CDRO
# 7  2014           98    Chautauqua    WRO
# 8  2014          756    Rensselaer   CDRO
# 9  2014          815  St. Lawrence  CNYRO
#
#                           Hospital Name  Total Births  Infants <2000 Gm  \
# 0             A O Fox Memorial Hospital           260                 0
# 1                 Adirondack Med Center           145                 1
# 2        Albany Medical Center Hospital          2058               245
# 3             Alice Hyde Medical Center           243                 5
# 4  Arnot Ogden Memorial Center Hospital          1425                65
# ...

# %% [markdown]
# # Examples with JSON

# %% [markdown]
# ## Example 1: PA- Percentage of Births that are Preterm

# %%
Preterm = pd.read_json('PretermBirth.json')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-3094728b9937> in <cell line: 1>()
# ----> 1 Preterm = pd.read_json('PretermBirth.json')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
Preterm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-eda5b4bc1a79> in <cell line: 1>()
# ----> 1 Preterm
#
# NameError: name 'Preterm' is not defined
